# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("the_office_series.csv", index_col = 0)

# %%
df.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
# 3       1   The Alliance  Just for a laugh, Jim agrees to an alliance wi...
# 4       1     Basketball  Michael and his staff challenge the warehouse ...
#
#    Ratings  Votes  Viewership  Duration            Date GuestStars  \
# 0      7.5   4936        11.2        23   24 March 2005        NaN
# 1      8.3   4801         6.0        23   29 March 2005        NaN
# 2      7.8   4024         5.8        22    5 April 2005        NaN
# 3      8.1   3915         5.4        23   12 April 2005        NaN
# 4      8.4   4294         5.0        23   19 April 2005        NaN
#
#           Director                                           Writers
# 0       Ken Kwapis  Ricky Gervais |Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                       B. J. Novak
# 2  Ken Whittingham                                  Paul Lieberstein
# 3     Bryan Gordon                                     Michael Schur
# 4     Greg Daniels                                      Greg Daniels

# %%
df.dtypes
# Out:
# Season            int64
# EpisodeTitle     object
# About            object
# Ratings         float64
# Votes             int64
# Viewership      float64
# Duration          int64
# Date             object
# GuestStars       object
# Director         object
# Writers          object
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.head(1)
# Out:
#    Season EpisodeTitle                                              About  \
# 0       1        Pilot  The premiere episode introduces the boss and s...
#
#    Ratings  Votes  Viewership  Duration       Date GuestStars    Director  \
# 0      7.5   4936        11.2        23 2005-03-24        NaN  Ken Kwapis
#
#                                             Writers
# 0  Ricky Gervais |Stephen Merchant and Greg Daniels

# %%
df_writers = df.assign(Writers=df.Writers.str.split("|")).explode('Writers')

# %%
df_writers = df_writers.assign(Writers=df_writers.Writers.str.split("and")).explode('Writers')

# %%
df_writers.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
#
#    Ratings  Votes  Viewership  Duration       Date GuestStars  \
# 0      7.5   4936        11.2        23 2005-03-24        NaN
# 0      7.5   4936        11.2        23 2005-03-24        NaN
# 0      7.5   4936        11.2        23 2005-03-24        NaN
# 1      8.3   4801         6.0        23 2005-03-29        NaN
# 2      7.8   4024         5.8        22 2005-04-05        NaN
#
#           Director            Writers
# 0       Ken Kwapis     Ricky Gervais
# 0       Ken Kwapis  Stephen Merchant
# 0       Ken Kwapis       Greg Daniels
# 1       Ken Kwapis        B. J. Novak
# 2  Ken Whittingham   Paul Lieberstein

# %%
print(df.shape, df_writers.shape)
# Out:
# (188, 11) (232, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188 entries, 0 to 187
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Season        188 non-null    int64
#  1   EpisodeTitle  188 non-null    object
#  2   About         188 non-null    object
#  3   Ratings       188 non-null    float64
#  4   Votes         188 non-null    int64
#  5   Viewership    188 non-null    float64
#  6   Duration      188 non-null    int64
#  7   Date          188 non-null    datetime64[ns]
#  8   GuestStars    29 non-null     object
#  9   Director      188 non-null    object
#  10  Writers       188 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 17.6+ KB

# %%
df.describe().T
# Out:
#             count         mean          std      min      25%       50%  \
# Season      188.0     5.468085     2.386245     1.00     3.00     6.000
# Ratings     188.0     8.237234     0.589930     6.60     7.80     8.200
# Votes       188.0  2838.228723  1063.165290  1832.00  2187.75  2614.000
# Viewership  188.0     7.246330     2.066012     3.25     5.99     7.535
# Duration    188.0    27.053191     6.937254    19.00    22.00    23.000
#
#                  75%       max
# Season         7.250      9.00
# Ratings        8.600      9.80
# Votes       3144.250  10515.00
# Viewership     8.425     22.91
# Duration      30.000     60.00

# %%
df.describe(include = "object").T
# Out:
#              count unique                                                top  \
# EpisodeTitle   188    188                                              Pilot
# About          188    188  The premiere episode introduces the boss and s...
# GuestStars      29     28                                          Amy Adams
# Director       188     54                                    Randall Einhorn
# Writers        188     47                                       Mindy Kaling
#
#              freq
# EpisodeTitle    1
# About           1
# GuestStars      2
# Director       15
# Writers        20

# %%
df.isnull().sum()
# Out:
# Season            0
# EpisodeTitle      0
# About             0
# Ratings           0
# Votes             0
# Viewership        0
# Duration          0
# Date              0
# GuestStars      159
# Director          0
# Writers           0
# dtype: int64

# %%
df_clean = df.fillna("Nobody")

# %%
df_clean.isnull().sum()
# Out:
# Season          0
# EpisodeTitle    0
# About           0
# Ratings         0
# Votes           0
# Viewership      0
# Duration        0
# Date            0
# GuestStars      0
# Director        0
# Writers         0
# dtype: int64

# %%
df_clean.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
# 3       1   The Alliance  Just for a laugh, Jim agrees to an alliance wi...
# 4       1     Basketball  Michael and his staff challenge the warehouse ...
#
#    Ratings  Votes  Viewership  Duration       Date GuestStars  \
# 0      7.5   4936        11.2        23 2005-03-24     Nobody
# 1      8.3   4801         6.0        23 2005-03-29     Nobody
# 2      7.8   4024         5.8        22 2005-04-05     Nobody
# 3      8.1   3915         5.4        23 2005-04-12     Nobody
# 4      8.4   4294         5.0        23 2005-04-19     Nobody
#
#           Director                                           Writers
# 0       Ken Kwapis  Ricky Gervais |Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                       B. J. Novak
# 2  Ken Whittingham                                  Paul Lieberstein
# 3     Bryan Gordon                                     Michael Schur
# 4     Greg Daniels                                      Greg Daniels
